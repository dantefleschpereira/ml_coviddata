# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Análise Exploratória de Dados

# %%
df = pd.read_excel(r'C:\Nucleo_IA\COVID\ML\dataset0709.xlsx')

# %%
df.head(15)
# Out:
#     idade sexo    raca tagabismo comorbidade1 comorbidade2 comorbidade3  \
# 0      41    M  branca       nao      nenhuma      nenhuma       nenhum
# 1      77    F  branca       sim          HAS      nenhuma       nenhum
# 2      67    M  branca    previo          HAS           DM       nenhum
# 3      51    M  branca       nao          HAS     renal-hd       nenhum
# 4      51    M  branca       nao          HAS     renal-hd       nenhum
# 5      64    F  branca       nao          HAS      nenhuma       nenhum
# 6      38    M   preta       nao     renal-hd      nenhuma       nenhum
# 7      37    M  branca       sim          HIV   oncologico       nenhum
# 8      82    F  branca       nao          HAS   oncologico       nenhum
# 9      45    M  branca       nao      nenhuma      nenhuma       nenhum
# 10     63    M  branca    previo          HAS           DM   oncologica
# 11     79    M   preta       nao          HAS      nenhuma       nenhum
# ...

# %% [markdown]
# Valores Vazios
# - Deletar linhas/colunas vazias
# - Deletar linhas que possuem valores vazios
# - Preencher valores vazios (último valor)

# %%
# deletar linhas e colunas completamente vazias
# df = df.dropna(how='all', axis=1)

# deletar linhas que possuem pelo menos 1 valor vazio
# df = df.dropna()

# %%
# preencher com o último valor
df = df.ffill()

# %%
# deletar colunas incompletas
df = df.drop(columns='antibiotico1')
df = df.drop(columns='antibiotico2')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idade                     431 non-null    int64
#  1   sexo                      431 non-null    object
#  2   raca                      431 non-null    object
#  3   tagabismo                 431 non-null    object
#  4   comorbidade1              431 non-null    object
#  5   comorbidade2              431 non-null    object
#  6   comorbidade3              431 non-null    object
#  7   comorbidade4              431 non-null    object
#  8   trombo_na_internacao      431 non-null    object
#  9   desfecho                  431 non-null    int64
#  10  anti-inflamatorio1        431 non-null    object
#  11  anti-inflamatorio2        431 non-null    object
#  12  anti-inflamatorio3        431 non-null    object
# ...

# %%
df.head(15)
# Out:
#     idade sexo    raca tagabismo comorbidade1 comorbidade2 comorbidade3  \
# 0      41    M  branca       nao      nenhuma      nenhuma       nenhum
# 1      77    F  branca       sim          HAS      nenhuma       nenhum
# 2      67    M  branca    previo          HAS           DM       nenhum
# 3      51    M  branca       nao          HAS     renal-hd       nenhum
# 4      51    M  branca       nao          HAS     renal-hd       nenhum
# 5      64    F  branca       nao          HAS      nenhuma       nenhum
# 6      38    M   preta       nao     renal-hd      nenhuma       nenhum
# 7      37    M  branca       sim          HIV   oncologico       nenhum
# 8      82    F  branca       nao          HAS   oncologico       nenhum
# 9      45    M  branca       nao      nenhuma      nenhuma       nenhum
# 10     63    M  branca    previo          HAS           DM   oncologica
# 11     79    M   preta       nao          HAS      nenhuma       nenhum
# ...

# %%
view = df[['comorbidade1','comorbidade2','comorbidade3','trombo_na_internacao', 'desfecho']]
display(view)
# Out:
#     comorbidade1 comorbidade2 comorbidade3 trombo_na_internacao  desfecho
# 0        nenhuma      nenhuma       nenhum               nenhum         4
# 1            HAS      nenhuma       nenhum               nenhum         4
# 2            HAS           DM       nenhum               nenhum         4
# 3            HAS     renal-hd       nenhum               nenhum         1
# 4            HAS     renal-hd       nenhum               nenhum         1
# ..           ...          ...          ...                  ...       ...
# 426          HAS      nenhuma       nenhum               nenhum         1
# 427      nenhuma      nenhuma       nenhum               nenhum         4
# 428           DM          HAS       nenhum               nenhum         1
# 429          HAS          ICC       nenhum               nenhum         2
# 430           DM          HAS       nenhum               nenhum         1
#
# [431 rows x 5 columns]

# %%
df['desfecho']==1  # DESFECHO (1-alta/ 2-UTI/ 3-óbito/4-fim isolamento/5-transf.)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 426     True
# 427    False
# 428     True
# 429    False
# 430     True
# Name: desfecho, Length: 431, dtype: bool

# %%
df[df['desfecho']==1] # select * from df where desfecho
# Out:
#      idade sexo    raca tagabismo comorbidade1 comorbidade2 comorbidade3  \
# 3       51    M  branca       nao          HAS     renal-hd       nenhum
# 4       51    M  branca       nao          HAS     renal-hd       nenhum
# 5       64    F  branca       nao          HAS      nenhuma       nenhum
# 6       38    M   preta       nao     renal-hd      nenhuma       nenhum
# 11      79    M   preta       nao          HAS      nenhuma       nenhum
# ..     ...  ...     ...       ...          ...          ...          ...
# 424     43    F   preta       nao      nenhuma      nenhuma       nenhum
# 425     62    F  branca       nao      nenhuma      nenhuma       nenhum
# 426     50    M  branca    previo          HAS      nenhuma       nenhum
# 428     58    M  branca    previo           DM          HAS       nenhum
# 430     52    M  branca       nao           DM          HAS       nenhum
#
#     comorbidade4 trombo_na_internacao  desfecho  \
# ...

# %% [markdown]
# #### Calculando e imprimindo histogramas sobre colunas numéricas

# %%
#%matplotlib inline # only in a Jupyter notebook
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
print('Menor valor de idade: ', df['idade'].min())
print('Maior valor de idade: ', df['idade'].max())
# Out:
# Menor valor de idade:  19
# Maior valor de idade:  96

# %% [markdown]
# #### Ajustando a escala dos atributos numéricos quantitativos

# %%
df[df['proteina c (mg/dl)']=='x'] # select * from df where
# Out:
# Empty DataFrame
# Columns: [idade, sexo, raca, tagabismo, comorbidade1, comorbidade2, comorbidade3, comorbidade4, trombo_na_internacao, desfecho, anti-inflamatorio1, anti-inflamatorio2, anti-inflamatorio3, anti-inflamatorio_previo, profilaxia_de_trombo1, profilaxia_de_trombo2, anticoagulante_previo, proteina c (mg/dl), ferritina (ng/ml), leucócitos ( /ul), creatinina (mg/dl), ureia(mg/dl), d-dimeros (ng/ml), reinfeccao, sintomas]
# Index: []

# %%
# value counts
proteina_c = df['proteina c (mg/dl)'].value_counts()
display(proteina_c)
# Out:
# 0.0     47
# 0.5     11
# 8.7      7
# 8.9      6
# 5.4      6
#         ..
# 7.5      1
# 47.6     1
# 21.8     1
# 32.3     1
# 0.4      1
# Name: proteina c (mg/dl), Length: 186, dtype: int64

# %%
df = df.mask(df == 'x', 0)

# %%
df = df.mask(df == 'X', 0)

# %%
proteina_c = df['proteina c (mg/dl)'].value_counts()
display(proteina_c)
# Out:
# 0.0     47
# 0.5     11
# 8.7      7
# 8.9      6
# 5.4      6
#         ..
# 7.5      1
# 47.6     1
# 21.8     1
# 32.3     1
# 0.4      1
# Name: proteina c (mg/dl), Length: 186, dtype: int64

# %%
df.head(15)
# Out:
#     idade sexo    raca tagabismo comorbidade1 comorbidade2 comorbidade3  \
# 0      41    M  branca       nao      nenhuma      nenhuma       nenhum
# 1      77    F  branca       sim          HAS      nenhuma       nenhum
# 2      67    M  branca    previo          HAS           DM       nenhum
# 3      51    M  branca       nao          HAS     renal-hd       nenhum
# 4      51    M  branca       nao          HAS     renal-hd       nenhum
# 5      64    F  branca       nao          HAS      nenhuma       nenhum
# 6      38    M   preta       nao     renal-hd      nenhuma       nenhum
# 7      37    M  branca       sim          HIV   oncologico       nenhum
# 8      82    F  branca       nao          HAS   oncologico       nenhum
# 9      45    M  branca       nao      nenhuma      nenhuma       nenhum
# 10     63    M  branca    previo          HAS           DM   oncologica
# 11     79    M   preta       nao          HAS      nenhuma       nenhum
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idade                     431 non-null    int64
#  1   sexo                      431 non-null    object
#  2   raca                      431 non-null    object
#  3   tagabismo                 431 non-null    object
#  4   comorbidade1              431 non-null    object
#  5   comorbidade2              431 non-null    object
#  6   comorbidade3              431 non-null    object
#  7   comorbidade4              431 non-null    object
#  8   trombo_na_internacao      431 non-null    object
#  9   desfecho                  431 non-null    int64
#  10  anti-inflamatorio1        431 non-null    object
#  11  anti-inflamatorio2        431 non-null    object
#  12  anti-inflamatorio3        431 non-null    object
# ...

# %% [markdown]
# ### Pré-processamento

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
nomes_atributos_numericos = ['idade','proteina c (mg/dl)','ferritina (ng/ml)','leucócitos ( /ul)','creatinina (mg/dl)','ureia(mg/dl)','d-dimeros (ng/ml)']
atributos_numericos       = nomes_atributos_numericos
nomes_atributos           = nomes_atributos_numericos

# %%
nomes_atributos
# Out:
# ['idade',
#  'proteina c (mg/dl)',
#  'ferritina (ng/ml)',
#  'leucócitos ( /ul)',
#  'creatinina (mg/dl)',
#  'ureia(mg/dl)',
#  'd-dimeros (ng/ml)']

# %%
df[nomes_atributos]
# Out:
#      idade  proteina c (mg/dl)  ferritina (ng/ml)  leucócitos ( /ul)  \
# 0       41                 8.0                  0               4830
# 1       77                14.7                  0               5280
# 2       67                 0.0                  0               8650
# 3       51                 6.2                  0               9590
# 4       51                32.0                  0               4230
# ..     ...                 ...                ...                ...
# 426     50                 0.0                  0               7100
# 427     92                 1.7                  0               7056
# 428     58                 0.0                  0              10580
# 429     88                 5.2                  0              11220
# 430     52                 6.6                  0               8530
#
#      creatinina (mg/dl)  ureia(mg/dl)  d-dimeros (ng/ml)
# 0                  0.76          36.0                  0
# ...

# %%
atributos_categoricos = ['sintomas','raca','tagabismo','comorbidade1','comorbidade2','comorbidade3','trombo_na_internacao','sintomas','anti-inflamatorio_previo','anticoagulante_previo','reinfeccao']
atributos_binarios    = ['sexo']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df_treino[atributos_numericos])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(df_treino[atributos_numericos])
#
# NameError: name 'df_treino' is not defined

# %%
# scaler.mean_

# %%
scaler.scale_

# %%
X = scaler.transform(df_treino[atributos_numericos])
X

# %%
df_treino[atributos_binarios].head()

# %%
X = np.concatenate((X, df_treino[atributos_binarios]),axis=1)
X

# %%
nomes_atributos = np.append(nomes_atributos,atributos_binarios)
nomes_atributos

# %%
df_treino.head()

# %% [markdown]
# #### Binarizando atributos categóricos (One Hot Encoding)

# %%
df_treino['raca'].value_counts()

# %%
df_treino['tagabismo'].value_counts()

# %%
df_treino['anti-inflamatorio1'].value_counts()

# %%
df_treino['comorbidade1'].value_counts()

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelBinarizer

# %%
lb_raca = LabelBinarizer()
raca = lb_raca.fit_transform(df_treino['raca'].values)
print("Classes aprendidas: ",lb_raca.classes_)
print("Primeiras 5 linhas dos dados: ")
print(raca[0:5,])

# %%
lb_tagabismo = LabelBinarizer()
tagabismo = lb_tagabismo.fit_transform(df_treino['tagabismo'].values)
print("Classes aprendidas: ",lb_tagabismo.classes_)
print("Primeiras 5 linhas dos dados: ")
print(tagabismo[0:5,])

# %%
df['anti-inflamatorio1'].values

# %%
lb_anti_inflamatorio1 = LabelBinarizer()
anti_inflamatorio1 = lb_anti_inflamatorio1.fit_transform(df_treino['anti-inflamatorio1'].values)
print("Classes aprendidas: ",lb_anti_inflamatorio1.classes_)
print("Primeiras 5 linhas dos dados: ")
print(anti_inflamatorio1[0:5,])

# %%
lb_anti_inflamatorio2 = LabelBinarizer()
anti_inflamatorio2 = lb_anti_inflamatorio2.fit_transform(df_treino['anti-inflamatorio2'].values)
print("Classes aprendidas: ",lb_anti_inflamatorio2.classes_)
print("Primeiras 5 linhas dos dados: ")
print(anti_inflamatorio2[0:5,])

# %%
lb_anti_inflamatorio3 = LabelBinarizer()
anti_inflamatorio3 = lb_anti_inflamatorio3.fit_transform(df_treino['anti-inflamatorio3'].values)
print("Classes aprendidas: ",lb_anti_inflamatorio3.classes_)
print("Primeiras 5 linhas dos dados: ")
print(anti_inflamatorio3[0:5,])

# %%
lb_comorbidade1 = LabelBinarizer()
comorbidade1 = lb_comorbidade1.fit_transform(df_treino['comorbidade1'].values)
print("Classes aprendidas: ",lb_comorbidade1.classes_)
print("Primeiras 5 linhas dos dados: ")
print(comorbidade1[0:5,])

# %%
lb_comorbidade2 = LabelBinarizer()
comorbidade2 = lb_comorbidade2.fit_transform(df_treino['comorbidade2'].values)
print("Classes aprendidas: ",lb_comorbidade2.classes_)
print("Primeiras 5 linhas dos dados: ")
print(comorbidade2[0:5,])

# %%
df['trombo_na_internacao'].values

# %%
# df['trombo_na_internacao'],['desfecho'],['anti-inflamatorio1'],['anti-inflamatorio2'],['anti-inflamatorio3'],['profilaxia_de_trombo1'],['profilaxia_de_trombo2'],['proteina c (mg/dl)'],['ferritina (ng/ml)'],['leucócitos ( /ul)'],['creatinina (mg/dl)'],['ureia(mg/dl)'],['d-dimeros (ng/ml')]

# %%
lb_anti_inflamatorio_previo = LabelBinarizer()
anti_inflamatorio_previo = lb_anti_inflamatorio_previo.fit_transform(df_treino['anti-inflamatorio_previo'].values)
print("Classes aprendidas: ",lb_anti_inflamatorio_previo.classes_)
print("Primeiras 5 linhas dos dados: ")
print(anti_inflamatorio_previo[0:5,])

# %%
df_treino['anticoagulante_previo'].values

# %%
lb_anticoagulante_previo = LabelBinarizer()
anti_anticoagulante_previo = lb_anticoagulante_previo.fit_transform(df_treino['anticoagulante_previo'].values)
print("Classes aprendidas: ",lb_anticoagulante_previo.classes_)
print("Primeiras 5 linhas dos dados: ")
print(anti_anticoagulante_previo[0:5,])

# %%
df['profilaxia_de_trombo1']

# %%
# lb_profilaxia_de_trombo1 = LabelBinarizer()
# profilaxia_de_trombo1 = lb_profilaxia_de_trombo1.fit_transform(df_treino['profilaxia_de_trombo1'].values)
# print("Classes aprendidas: ",lb_profilaxia_de_trombo1.classes_)
# print("Primeiras 5 linhas dos dados: ")
# print(profilaxia_de_trombo1[0:5,])
