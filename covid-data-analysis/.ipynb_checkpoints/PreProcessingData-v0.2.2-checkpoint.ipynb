# %%
import math
import numpy as np
import pandas as pd
from dateutil.parser import parse

pd.set_option('display.max_columns', None)

# %%
def loadCSVFile(csvPath, sepStyle, encodeStyle):
    return pd.read_csv(csvPath, sep=sepStyle, encoding=encodeStyle, low_memory=False)

# %%
def mergeDataFrames(leftDF, rightDF, keyColumnL, keyColumnR, suffixTuple):
    return leftDF.merge(rightDF, how='left', left_on=keyColumnL, right_on=keyColumnR, suffixes=suffixTuple)

# %%
def mergeDtHrUTI(listDtInUTI, listHrInUTI, listDtOutUTI, listHrOutUTI):
    listDTHR_InUTI, listDTHR_OutUTI= [], []
    
    for tplDtHrInUTI in zip(listDtInUTI, listHrInUTI):
        inDtUTI = tplDtHrInUTI[0]
        inHrUTI = tplDtHrInUTI[1]
        if type(inDtUTI) != str and type(inHrUTI) != str:
            if math.isnan(inDtUTI) == True or math.isnan(inHrUTI) == True:
                listDTHR_InUTI.append(np.nan)
        else:
            listDTHR_InUTI.append(' '.join(tplDtHrInUTI))
            
    for tplDtHrOutUTI in zip(listDtOutUTI, listHrOutUTI):
        outDtUTI = tplDtHrOutUTI[0]
        outHrUTI = tplDtHrOutUTI[1]
        if type(outDtUTI) != str and type(outHrUTI) != str:
            if math.isnan(outDtUTI) == True or math.isnan(outHrUTI) == True:
                listDTHR_OutUTI.append(np.nan)
        else:
            listDTHR_OutUTI.append(' '.join(tplDtHrOutUTI))
            
    return listDTHR_InUTI, listDTHR_OutUTI

# %%
def timeCounterBtwnDates(bDate, eDate):
    _bDate = parse(bDate, dayfirst=True).ctime()
    _bDate = parse(_bDate, dayfirst=True)
    
    _eDate = parse(eDate, dayfirst=True).ctime()
    _eDate = parse(_eDate, dayfirst=True)

    delta = _eDate - _bDate

    totalDays = delta.total_seconds()/86400
    
    return totalDays

# %%
def getDaysCountByRow(row, posREG, posALTA, posLEITO, posInUTI, posOutUTI):
    if type(row[posREG]) == str and type(row[posInUTI]) == str and type(row[posOutUTI]) == str:
        if type(row[posLEITO]) != str or row[posLEITO] == '':
           Pre_UTITime = timeCounterBtwnDates(bDate=row[posREG], eDate=row[posInUTI])
        else:
           Pre_UTITime = timeCounterBtwnDates(bDate=row[posLEITO], eDate=row[posInUTI])
        UTI_TIME = timeCounterBtwnDates(bDate=row[posInUTI], eDate=row[posOutUTI])
    else:
       if type(row[posREG]) == str and type(row[posALTA]) == str and type(row[posInUTI]) == float and type(row[posOutUTI]) == float:
          Pre_UTITime = timeCounterBtwnDates(bDate=row[posREG], eDate=row[posALTA])
          UTI_TIME = 0.0
       else:
          if type(row[posREG]) == float or type(row[posALTA]) == float:
             #print('Maybe PANIC here too!')
             Pre_UTITime = np.nan
             UTI_TIME = np.nan
    
#    if type(row[posREG]) == float and type(row[posALTA]) == str and type(row[posInUTI]) == float and type(row[posOutUTI]) == float:
#        Pre_UTITime = np.nan
#        UTI_TIME = np.nan
    
    return Pre_UTITime, UTI_TIME

# %%
def getTimeForEachDFRow(DFRows):
    list_PreUTITime, list_UTITime = [], []
    
    iREG=DF_REG_EST_UTI.columns.get_loc('DTHR_REGISTRO')
    iALTA=DF_REG_EST_UTI.columns.get_loc('DTHR_ALTA')
    iLEITO=DF_REG_EST_UTI.columns.get_loc('DTHR_LEITO')
    iInUTI=DF_REG_EST_UTI.columns.get_loc('DTHR_IN_UTI')
    iOutUTI=DF_REG_EST_UTI.columns.get_loc('DTHR_OUT_UTI')
    for row in DFRows:
      pUTI, UTI = getDaysCountByRow(row=row, posREG=iREG, posALTA=iALTA, posLEITO=iLEITO, posInUTI=iInUTI, posOutUTI=iOutUTI)
      list_PreUTITime.append(pUTI)
      list_UTITime.append(UTI)
    
    return list_PreUTITime, list_UTITime

# %%
if __name__ == '__main__':
    
    # Carrega os dados
    DF_REGISTRO = loadCSVFile(csvPath='atendimentos.csv', encodeStyle='latin1', sepStyle=';')
    DF_ESTUDO = loadCSVFile(csvPath='estudo.csv', encodeStyle='latin1', sepStyle=';')
    DF_UTI = loadCSVFile(csvPath='uti.csv', encodeStyle='latin1', sepStyle=';')    
    
    #Remove duplicações
    DF_REGISTRO = DF_REGISTRO.drop_duplicates()
    DF_ESTUDO = DF_ESTUDO.drop_duplicates()
    DF_UTI = DF_UTI.drop_duplicates()

    #Corrige DF_UTI para que tenha uma entrada para cada passagem na UTI
#    print(DF_UTI.head(50))
    # Para corrigir DF_UTI, vamos precisar usar datas de entrada em leito (se vazio usamos DTHR_REGISTRO)
    DF_UTI['DTHR_LEITO'] = ''
    # Precisamos ordenar por atendimento e data-hora de entrada
    DF_UTI['DATA_HORA_ENTRADA'] = DF_UTI['DT_ENTRADA']+' '+DF_UTI['HR_ENTRADA']
    DF_UTI['DATA_HORA_ENTRADA'] = pd.to_datetime(DF_UTI.DATA_HORA_ENTRADA,format='%d/%m/%Y %H:%M:%S')
    DF_UTI = DF_UTI.sort_values(by=['CD_ATENDIMENTO','DATA_HORA_ENTRADA'],ignore_index=True)
#    print(DF_UTI.head(50))
    # Vamos precisar também contar a reentrada
    DF_UTI['REENTRADA']=0
    i = 0
    j = 0
    DF_UTI2 = DF_UTI.copy()
    while i < len(DF_UTI.index)-1 :
      if DF_UTI.loc[i,'CD_ATENDIMENTO'] == DF_UTI.loc[i+1,'CD_ATENDIMENTO'] :
        if type(DF_UTI.loc[i,'DT_SAIDA']) != str or type(DF_UTI.loc[i,'HR_SAIDA']) != str :
          #HORROR: we don't know why this is happening
          print('PANIC!!!!!!!!!!!!')
          i=i+1
          j=i
        if timeCounterBtwnDates(bDate=DF_UTI.loc[i,'DT_SAIDA']+' '+DF_UTI.loc[i,'HR_SAIDA'], eDate=DF_UTI.loc[i+1,'DT_ENTRADA']+' '+DF_UTI.loc[i+1,'HR_ENTRADA']) < 1 :
#          print('merging two rows at: ',i)
          DF_UTI2.loc[j,'DT_SAIDA'] = DF_UTI.loc[i+1,'DT_SAIDA']
          DF_UTI2.loc[j,'HR_SAIDA'] = DF_UTI.loc[i+1,'HR_SAIDA']
          DF_UTI2 = DF_UTI2.drop([i+1])
          i = i+1
        else :
#          print('spliting UTI entrance at: ',i)
          DF_UTI2.loc[i+1,'DTHR_LEITO']=DF_UTI.loc[i,'DT_SAIDA']+' '+DF_UTI.loc[i,'HR_SAIDA']
          DF_UTI2.loc[i+1,'REENTRADA']=DF_UTI2.loc[j,'REENTRADA']+1
          i = i+1
          j = i
      else :
        i = i+1
        j = i

    DF_UTI = DF_UTI2

    #print(DF_UTI.head(50))

    #União das Tabelas REGISTRO e ESTUDO
    DF_REG_EST = mergeDataFrames(leftDF=DF_REGISTRO,
                                 rightDF=DF_ESTUDO,
                                 keyColumnL='CD_PACIENTE', keyColumnR='CD_PACIENTE_FROM_ESTUDO',
                                 suffixTuple=('_FROM_REG', '_FROM_EST'))
    
    # It seems the datatypes of the CD_ATENDIMENTO in different tables are not the same
    DF_REG_EST['CD_ATENDIMENTO'] = pd.to_numeric(DF_REG_EST['CD_ATENDIMENTO'])
    DF_UTI['CD_ATENDIMENTO'] = pd.to_numeric(DF_UTI['CD_ATENDIMENTO'])
    # Also sort before merging with UTI so we can check if it's working more easily
    DF_REG_EST = DF_REG_EST.sort_values(by=['CD_ATENDIMENTO'],ignore_index=True)

    #União das Tabelas REGISTRO-ESTUDO e UTI
    DF_REG_EST_UTI = mergeDataFrames(leftDF=DF_REG_EST,
                                     rightDF=DF_UTI,
                                     keyColumnL='CD_ATENDIMENTO', keyColumnR='CD_ATENDIMENTO',
                                     suffixTuple=('_FROM_MRG_REG_EST', '_FROM_UTI'))
    
    
    #Remove duplicações
    DF_REG_EST_UTI = DF_REG_EST_UTI.drop_duplicates()
    
    
    #União dos campos DT_ENTRADA + HR_ENTRADA e DT_SAIDA + HR_SAIDA
    lDtInUTI = DF_REG_EST_UTI['DT_ENTRADA'].values.tolist()
    lHrInUTI = DF_REG_EST_UTI['HR_ENTRADA'].values.tolist()
    lDtOutUTI = DF_REG_EST_UTI['DT_SAIDA'].values.tolist()
    lHrOutUTI = DF_REG_EST_UTI['HR_SAIDA'].values.tolist()
    
    listDTHR_InUTI, listDTHR_OutUTI = mergeDtHrUTI(listDtInUTI=lDtInUTI,
                                                   listHrInUTI=lHrInUTI,
                                                   listDtOutUTI=lDtOutUTI,
                                                   listHrOutUTI=lHrOutUTI)
    
    #Adicionando União anterior a tabela geral
    DF_REG_EST_UTI['DTHR_IN_UTI'] = listDTHR_InUTI
    DF_REG_EST_UTI['DTHR_OUT_UTI'] = listDTHR_OutUTI
    
    #Calculando e Adicionando numero de dias antes e durante a UTI
    list_PreUTITime, list_UTITime = getTimeForEachDFRow(DFRows=DF_REG_EST_UTI.values.tolist())
    
    DF_REG_EST_UTI['DIAS_PRE_UTI'] = list_PreUTITime
    DF_REG_EST_UTI['DIAS_NA_UTI'] = list_UTITime

#    i=0
#    j=0
#    while i < len(DF_UTI.index) :
#      if DF_REG_EST_UTI.loc[i,'DIAS_PRE_UTI'] < 0 or DF_REG_EST_UTI.loc[i,'DIAS_PRE_UTI'] < 0 :
#        j = j+1
#      i=i+1
#    print('ERROS ',j)
    # 228 linhas com numero negativos
    # ATTENTION DELETING NEGATIVE CALCULATED NUMBERS
    DF_REG_EST_UTI = DF_REG_EST_UTI[DF_REG_EST_UTI.DIAS_PRE_UTI>=0]
    DF_REG_EST_UTI = DF_REG_EST_UTI[DF_REG_EST_UTI.DIAS_NA_UTI>=0]
    print(DF_REG_EST_UTI.head(10))

    #print(DF_REG_EST['CD_ATENDIMENTO'].head(10))
    #print(DF_UTI.head(10))
    #print(DF_REG_EST_UTI['CD_ATENDIMENTO'].head(10),DF_REG_EST_UTI['REENTRADA'].head(10))
# Out:
#       ID        DTHR_REGISTRO    PORTA_ENTRADA DATA_INICIO_SINTOMAS  \
# 2   4463  08/07/2020 12:56:20              NaN                  NaN
# 3   4463  08/07/2020 12:56:20              NaN                  NaN
# 4   4463  08/07/2020 12:56:20              NaN                  NaN
# 5   4463  08/07/2020 12:56:20              NaN                  NaN
# 15  1149  27/03/2020 14:03:00              NaN                  NaN
# 16  1014  04/03/2020 13:59:22      PPUC adulto  29/02/2020 00:00:00
# 18   714  13/04/2020 11:35:08      PPUC adulto  07/04/2020 00:00:00
# 19  8743  20/08/2020 20:31:00              NaN                  NaN
# 23   998  06/03/2020 13:12:48  PPUC pediátrico                  NaN
# 26  1066  03/04/2020 16:02:12      PPUC adulto  28/03/2020 00:00:00
#
#    HISTORICO_VIAGEM                      PAIS_VISITADO  \
# 2               NaN                                NaN
# 3               NaN                                NaN
# 4               NaN                                NaN
# 5               NaN                                NaN
# 15              NaN                                NaN
# 16              SIM                    França e Italia
# 18              NaN                                NaN
# 19              NaN                                NaN
# 23              NÃO  Colega do pai estava em Singapura
# 26              NaN                                NaN
#
#             CIDADES_VISITADAS DATA_RETORNO COLETOU_AMOSTRA       LOCAL_COLETA  \
# 2                         NaN          NaN             SIM   9 N - INTERNACAO
# 3                         NaN          NaN             SIM   9 N - INTERNACAO
# 4                         NaN          NaN             SIM   9 N - INTERNACAO
# 5                         NaN          NaN             SIM   9 N - INTERNACAO
# 15                        NaN          NaN             NAO      UTI-CIRURGICA
# 16         Paris, Milão, Roma   24/02/2020             SIM              LACEN
# 18                        NaN          NaN             SIM              LACEN
# 19                        NaN          NaN             SIM   9 N - INTERNACAO
# 23  Singapura (colega do pai)          NaN             SIM              LACEN
# 26                        NaN          NaN             SIM  LACEN, Particular
#
#             DATA_COLETA PCR_INFLUENZA IFI_OUTRO_VIRUS PCR_COVID_19  \
# 2            08/07/2020           NaN             NaN     NEGATIVO
# 3            08/07/2020           NaN             NaN     NEGATIVO
# 4            08/07/2020           NaN             NaN     NEGATIVO
# 5            08/07/2020           NaN             NaN     NEGATIVO
# 15                  NaN           NaN             NaN     NEGATIVO
# 16           04/03/2020      NEGATIVO        NEGATIVO     NEGATIVO
# 18           09/04/2020           NaN             NaN     NEGATIVO
# 19  20/08/2020 21:10:53           NaN             NaN     POSITIVO
# 23           06/03/2020  EM ANDAMENTO    EM ANDAMENTO     NEGATIVO
# 26           02/04/2020           NaN             NaN     NEGATIVO
#
#    STATUS_COVID_FROM_MRG_REG_EST  STATUS_COVID_ORDEM  \
# 2                      NEGATIVOS                   3
# 3                      NEGATIVOS                   3
# 4                      NEGATIVOS                   3
# 5                      NEGATIVOS                   3
# 15                     NEGATIVOS                   3
# 16                     NEGATIVOS                   3
# 18                     NEGATIVOS                   3
# 19                   CONFIRMADOS                   1
# 23                     NEGATIVOS                   3
# 26                     NEGATIVOS                   3
#
#                                      DESFECHO  CD_ATENDIMENTO  \
# 2                               NÃO INFORMADO        925313.0
# 3                               NÃO INFORMADO        925313.0
# 4                               NÃO INFORMADO        925313.0
# 5                               NÃO INFORMADO        925313.0
# 15                              NÃO INFORMADO       1230987.0
# 16  ALTA AMBULATORIAL + ISOLAMENTO DOMICILIAR       1231126.0
# 18                                 INTERNAÇÃO       1231859.0
# 19                              NÃO INFORMADO       1232034.0
# 23  ALTA AMBULATORIAL + ISOLAMENTO DOMICILIAR       1235757.0
# 26                                 INTERNAÇÃO       1242110.0
#
#    DS_TP_ATENDIMENTO  CD_PACIENTE     GENERO             IDADE SN_OBITO  \
# 2          INTERNADO     454612.0  MASCULINO   42,498401826484        N
# 3          INTERNADO     454612.0  MASCULINO   42,498401826484        N
# 4          INTERNADO     454612.0  MASCULINO   42,498401826484        N
# 5          INTERNADO     454612.0  MASCULINO   42,498401826484        N
# 15         INTERNADO    1402382.0   FEMININO  83,3723744292237        N
# 16          URGENCIA    1464904.0   FEMININO  38,9312785388128        N
# 18         INTERNADO    1497679.0   FEMININO  53,2079908675799        S
# 19         INTERNADO     541053.0   FEMININO  76,2655251141553        N
# 23          URGENCIA    2337728.0  MASCULINO  6,05456621004566        N
# 26         INTERNADO    2338381.0   FEMININO  42,0162100456621        N
#
#    DIAGNOSTICO_SARS OBITO_SARS    TIPO_SAIDA TIPO_OBITO            DTHR_ALTA  \
# 2               NÃO        NÃO          ALTA        NaN  07/10/2020 13:13:46
# 3               NÃO        NÃO          ALTA        NaN  07/10/2020 13:13:46
# 4               NÃO        NÃO          ALTA        NaN  07/10/2020 13:13:46
# 5               NÃO        NÃO          ALTA        NaN  07/10/2020 13:13:46
# 15              NÃO        NÃO          ALTA        NaN  04/05/2020 12:53:00
# 16              NÃO        NÃO  AMBULATORIAL        NaN  04/03/2020 15:49:00
# 18              NÃO        NÃO         ÓBITO        NaN  14/05/2020 01:16:59
# 19              NÃO        NÃO          ALTA        NaN  10/09/2020 15:22:26
# 23              NÃO        NÃO  AMBULATORIAL        NaN  06/03/2020 14:25:00
# 26              NÃO        NÃO          ALTA        NaN  16/04/2020 18:50:00
#
#    CD_CID   DS_ESPECIALID_SAI REINTER_30D CARATER_ATENDIMENTO  EMERG_SERVICO  \
# 2    K263       NEUROCIRURGIA         NÃO            URGÊNCIA      PRONTOPUC
# 3    K263       NEUROCIRURGIA         NÃO            URGÊNCIA      PRONTOPUC
# 4    K263       NEUROCIRURGIA         NÃO            URGÊNCIA      PRONTOPUC
# 5    K263       NEUROCIRURGIA         NÃO            URGÊNCIA      PRONTOPUC
# 15   J180           GERIATRIA         NÃO            URGÊNCIA      PRONTOPUC
# 16   B972      CLINICA MEDICA         NÃO            URGÊNCIA      PRONTOPUC
# 18   I200      CLINICA MEDICA         NÃO            URGÊNCIA      PRONTOSUS
# 19    C20          NEFROLOGIA         NÃO            URGÊNCIA      PRONTOPUC
# 23    J00      CLINICA MEDICA         NÃO            URGÊNCIA      PRONTOPUC
# 26   A418  MEDICINA INTENSIVA         NÃO             ELETIVO  NÃO INFORMADO
#
#       EMERG_RISCO CID_DIAG_ATEND           CID_CAPITULO_DIAG BLOCO_CENTRAL_ST  \
# 2         LARANJA           K263          Aparelho digestivo              SIM
# 3         LARANJA           K263          Aparelho digestivo              SIM
# 4         LARANJA           K263          Aparelho digestivo              SIM
# 5         LARANJA           K263          Aparelho digestivo              SIM
# 15       VERMELHO           J180       Aparelho respiratório              NÃO
# 16          VERDE           B972  Infecciosas e parasitárias              NÃO
# 18        LARANJA           J960       Aparelho respiratório              SIM
# 19        LARANJA            C20        Neoplasias (tumores)              NÃO
# 23          VERDE            J00       Aparelho respiratório              NÃO
# 26  NÃO INFORMADO           A419  Infecciosas e parasitárias              NÃO
#
#    HEMODINAMICA_ST EX_LAB_ST EX_IMG_ST EX_OUTROS_ST  CD_PACIENTE_FROM_ESTUDO  \
# 2              SIM       SIM       SIM          SIM                 454612.0
# 3              SIM       SIM       SIM          SIM                 454612.0
# 4              SIM       SIM       SIM          SIM                 454612.0
# 5              SIM       SIM       SIM          SIM                 454612.0
# 15             NÃO       SIM       SIM          NÃO                1402382.0
# 16             NÃO       SIM       NÃO          NÃO                1464904.0
# 18             NÃO       SIM       SIM          SIM                1497679.0
# 19             NÃO       SIM       SIM          SIM                 541053.0
# 23             NÃO       SIM       NÃO          NÃO                2337728.0
# 26             NÃO       SIM       SIM          SIM                2338381.0
#
#    COMPETENCIA PORTA_ENTRADA_FROM_ESTUDO DATA_INICIO_SINTOMAS_FROM_ESTUDO  \
# 2   01/07/2020                       NaN                              NaN
# 3   01/07/2020                       NaN                              NaN
# 4   01/07/2020                       NaN                              NaN
# 5   01/07/2020                       NaN                              NaN
# 15  01/03/2020                       NaN                              NaN
# 16  01/03/2020               PPUC adulto                       29/02/2020
# 18  01/04/2020               PPUC adulto                       07/04/2020
# 19  20/08/2020                       NaN                              NaN
# 23  01/03/2020           PPUC pediátrico                              NaN
# 26  01/04/2020               PPUC adulto                       28/03/2020
#
#    HISTORICO_VIAGEM_FROM_ESTUDO CIDADES_VISITADAS_FROM_ESTUDO  \
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# 15                          NaN                           NaN
# 16                          SIM            Paris, Milão, Roma
# 18                          NaN                           NaN
# 19                          NaN                           NaN
# 23                          NAO     Singapura (colega do pai)
# 26                          NaN                           NaN
#
#    LOCAL_COLETA_FROM_ESTUDO DATA_COLETA_FROM_ESTUDO PCR_COVID_19_FROM_ESTUDO  \
# 2          9 N - INTERNACAO              08/07/2020                 NEGATIVO
# 3          9 N - INTERNACAO              08/07/2020                 NEGATIVO
# 4          9 N - INTERNACAO              08/07/2020                 NEGATIVO
# 5          9 N - INTERNACAO              08/07/2020                 NEGATIVO
# 15            UTI-CIRURGICA              11/07/2020                 POSITIVO
# 16                    LACEN              04/03/2020                 NEGATIVO
# 18                    LACEN              09/04/2020                 NEGATIVO
# 19         9 N - INTERNACAO     20/08/2020 21:10:53                 POSITIVO
# 23                    LACEN              06/03/2020                 NEGATIVO
# 26        LACEN, Particular              02/04/2020                 NEGATIVO
#
#                          DESFECHO_FROM_ESTUDO TIPO_REGISTRO  \
# 2                                  INTERNAÇÃO             A
# 3                                  INTERNAÇÃO             A
# 4                                  INTERNAÇÃO             A
# 5                                  INTERNAÇÃO             A
# 15                    ÓBITO POR OUTRAS CAUSAS             A
# 16  ALTA AMBULATORIAL + ISOLAMENTO DOMICILIAR             M
# 18                                 INTERNAÇÃO             M
# 19                                 INTERNAÇÃO             A
# 23  ALTA AMBULATORIAL + ISOLAMENTO DOMICILIAR             M
# 26                                 INTERNAÇÃO             M
#
#    SN_IFI_OV_SINCICIAL_RESP SN_IFI_OV_PARAINFLU3 SN_IFI_OV_PARAINFLU2  \
# 2                         N                    N                    N
# 3                         N                    N                    N
# 4                         N                    N                    N
# 5                         N                    N                    N
# 15                        N                    N                    N
# 16                        N                    N                    N
# 18                        N                    N                    N
# 19                        N                    N                    N
# 23                        N                    N                    N
# 26                        N                    N                    N
#
#    SN_IFI_OV_PARAINFLU1 SN_IFI_OV_INFLUA SN_IFI_OV_INFLUB  \
# 2                     N                N                N
# 3                     N                N                N
# 4                     N                N                N
# 5                     N                N                N
# 15                    N                N                N
# 16                    N                N                N
# 18                    N                N                N
# 19                    N                N                N
# 23                    N                N                N
# 26                    N                N                N
#
#    SN_IFI_OV_ADENOVIRUS SN_CRIT_CONTATO_CASO_COVID  \
# 2                     N                          N
# 3                     N                          N
# 4                     N                          N
# 5                     N                          N
# 15                    N                          N
# 16                    N                          N
# 18                    N                          N
# 19                    N                          N
# 23                    N                          N
# 26                    N                          N
#
#    SN_CRIT_CONTATO_CASO_SUSPEITO  SN_CRIT_PROF_SAUDE_HOSPITAL  \
# 2                              N                          NaN
# 3                              N                          NaN
# 4                              N                          NaN
# 5                              N                          NaN
# 15                             N                          NaN
# 16                             N                          NaN
# 18                             N                          NaN
# 19                             N                          NaN
# 23                             N                          NaN
# 26                             N                          NaN
#
#    SN_CRIT_PROF_SAUDE_OUT SN_CRIT_SRAG SN_CRIT_SINDROME_GRIPAL  \
# 2                       N            N                       N
# 3                       N            N                       N
# 4                       N            N                       N
# 5                       N            N                       N
# 15                      N            N                       N
# 16                      N            N                       N
# 18                      N            S                       N
# 19                      N            N                       N
# 23                      N            N                       N
# 26                      N            S                       N
#
#    SN_CRIT_IGNORADO SN_CRIT_OUTROS SN_CRIT_PROT_COVID19 ESTUDO_TP_EXPOSICAO  \
# 2                 N              N                    N      HOSPITALAR HSL
# 3                 N              N                    N      HOSPITALAR HSL
# 4                 N              N                    N      HOSPITALAR HSL
# 5                 N              N                    N      HOSPITALAR HSL
# 15                N              N                    N      HOSPITALAR HSL
# 16                N              N                    N                 NaN
# 18                N              N                    N                 NaN
# 19                N              N                    N      HOSPITALAR HSL
# 23                N              N                    N                 NaN
# 26                N              N                    N                 NaN
#
#    ESTUDO_COMORB_PREV_HAS ESTUDO_COMORB_PREV_IAM ESTUDO_COMORB_PREV_IC  \
# 2                       N                      N                     N
# 3                       N                      N                     N
# 4                       N                      N                     N
# 5                       N                      N                     N
# 15                      N                      N                     N
# 16                      N                      N                     N
# 18                      N                      N                     N
# 19                      N                      N                     N
# 23                      N                      N                     N
# 26                      N                      N                     N
#
#    ESTUDO_COMORB_PREV_DRC ESTUDO_COMORB_PREV_DMI ESTUDO_COMORB_PREV_DMII  \
# 2                       N                      N                       N
# 3                       N                      N                       N
# 4                       N                      N                       N
# 5                       N                      N                       N
# 15                      N                      N                       N
# 16                      N                      N                       N
# 18                      N                      N                       N
# 19                      N                      N                       N
# 23                      N                      N                       N
# 26                      N                      N                       N
#
#    ESTUDO_COMORB_PREV_CARCINOMA ESTUDO_COMORB_PREV_ADENOMA  \
# 2                             N                          N
# 3                             N                          N
# 4                             N                          N
# 5                             N                          N
# 15                            N                          N
# 16                            N                          N
# 18                            N                          N
# 19                            N                          N
# 23                            N                          N
# 26                            N                          N
#
#    ESTUDO_COMORB_PREV_LINFOMA ESTUDO_COMORB_PREV_AVC ESTUDO_COMORB_PREV_ASMA  \
# 2                           N                      N                       N
# 3                           N                      N                       N
# 4                           N                      N                       N
# 5                           N                      N                       N
# 15                          N                      N                       N
# 16                          N                      N                       N
# 18                          N                      N                       N
# 19                          N                      N                       N
# 23                          N                      N                       N
# 26                          N                      N                       N
#
#    ESTUDO_COMORB_PREV_DPOC ESTUDO_COMORB_PREV_OBESIDADE  \
# 2                        N                            N
# 3                        N                            N
# 4                        N                            N
# 5                        N                            N
# 15                       N                            N
# 16                       N                            N
# 18                       N                            N
# 19                       N                            N
# 23                       N                            N
# 26                       N                            N
#
#    ESTUDO_COMORB_PREV_EPILEPSIA ESTUDO_COMORB_PREV_HIGIDO  \
# 2                             N                         N
# 3                             N                         N
# 4                             N                         N
# 5                             N                         N
# 15                            N                         N
# 16                            N                         N
# 18                            N                         N
# 19                            N                         N
# 23                            N                         N
# 26                            N                         N
#
#    ESTUDO_COMORB_PREV_OUTRAS  ESTUDO_CHARLSON ESTUDO_FR_DIA_COLETA  \
# 2                        NaN              NaN                  NaN
# 3                        NaN              NaN                  NaN
# 4                        NaN              NaN                  NaN
# 5                        NaN              NaN                  NaN
# 15                       NaN              NaN                  NaN
# 16                       NaN              NaN                  NaN
# 18                       NaN              NaN                  NaN
# 19                       NaN              NaN                  NaN
# 23                       NaN              NaN                  NaN
# 26                       NaN              NaN                  NaN
#
#     ESTUDO_FC_DIA_COLETA ESTUDO_PA_DIA_COLETA ESTUDO_TEMPERATURA_DIA_COLETA  \
# 2                    NaN                  NaN                           NaN
# 3                    NaN                  NaN                           NaN
# 4                    NaN                  NaN                           NaN
# 5                    NaN                  NaN                           NaN
# 15                   NaN                  NaN                           NaN
# 16                   NaN                  NaN                           NaN
# 18                   NaN                  NaN                           NaN
# 19                   NaN                  NaN                           NaN
# 23                   NaN                  NaN                           NaN
# 26                   NaN                  NaN                           NaN
#
#    ESTUDO_SATURACAO_DIA_COLETA  ESTUDO_APACHE2  ESTUDO_RISCO  \
# 2                          NaN             NaN           NaN
# 3                          NaN             NaN           NaN
# 4                          NaN             NaN           NaN
# 5                          NaN             NaN           NaN
# 15                         NaN             NaN           NaN
# 16                         NaN             NaN           NaN
# 18                         NaN             NaN           NaN
# 19                         NaN             NaN           NaN
# 23                         NaN             NaN           NaN
# 26                         NaN             NaN           NaN
#
#    ESTUDO_TRATAMENTO ESTUDO_COMORB_PREV_TX_ORG_SOL ESTUDO_CONDUTA  \
# 2                NaN                             N              L
# 3                NaN                             N              L
# 4                NaN                             N              L
# 5                NaN                             N              L
# 15               NaN                             N              L
# 16               NaN                             N              L
# 18               NaN                             N              L
# 19               NaN                             N              L
# 23               NaN                             N              L
# 26               NaN                             N              L
#
#    ESTUDO_LOCAL_CONTAMINACAO  ESTUDO_LOCAL_CONTAM_UI ESTUDO_DT_DESFECHO  \
# 2                        NaN                     NaN                NaN
# 3                        NaN                     NaN                NaN
# 4                        NaN                     NaN                NaN
# 5                        NaN                     NaN                NaN
# 15                       NaN                     NaN                NaN
# 16                       NaN                     NaN                NaN
# 18                       NaN                     NaN                NaN
# 19                       NaN                     NaN                NaN
# 23                       NaN                     NaN                NaN
# 26                       NaN                     NaN                NaN
#
#    ESTUDO_COMORB_PREV_DESCON ESTUDO_COMORB_PREV_DVP  \
# 2                          N                      N
# 3                          N                      N
# 4                          N                      N
# 5                          N                      N
# 15                         N                      N
# 16                         N                      N
# 18                         N                      N
# 19                         N                      N
# 23                         N                      N
# 26                         N                      N
#
#    ESTUDO_COMORB_PREV_DEMENCIA ESTUDO_COMORB_PREV_DTC ESTUDO_COMORB_PREV_UP  \
# 2                            N                      N                     N
# 3                            N                      N                     N
# 4                            N                      N                     N
# 5                            N                      N                     N
# 15                           N                      N                     N
# 16                           N                      N                     N
# 18                           N                      N                     N
# 19                           N                      N                     N
# 23                           N                      N                     N
# 26                           N                      N                     N
#
#    ESTUDO_COMORB_PREV_DFL ESTUDO_COMORB_PREV_DFM  \
# 2                       N                      N
# 3                       N                      N
# 4                       N                      N
# 5                       N                      N
# 15                      N                      N
# 16                      N                      N
# 18                      N                      N
# 19                      N                      N
# 23                      N                      N
# 26                      N                      N
#
#    ESTUDO_COMORB_PREV_HEMIPLEGIA ESTUDO_COMORB_PREV_LEUCEMIA  \
# 2                              N                           N
# 3                              N                           N
# 4                              N                           N
# 5                              N                           N
# 15                             N                           N
# 16                             N                           N
# 18                             N                           N
# 19                             N                           N
# 23                             N                           N
# 26                             N                           N
#
#    ESTUDO_COMORB_PREV_HIV ESTUDO_COMORB_PREV_TUL ESTUDO_COMORB_PREV_TUM  \
# 2                       N                      N                      N
# 3                       N                      N                      N
# 4                       N                      N                      N
# 5                       N                      N                      N
# 15                      N                      N                      N
# 16                      N                      N                      N
# 18                      N                      N                      N
# 19                      N                      N                      N
# 23                      N                      N                      N
# 26                      N                      N                      N
#
#    STATUS_COVID_FROM_UTI  CD_PACIENTE_FROM_UTI  CD_LEITO  CD_UNIDADE  \
# 2              NEGATIVOS              454612.0    1607.0         7.0
# 3              NEGATIVOS              454612.0    1613.0         7.0
# 4              NEGATIVOS              454612.0    2736.0         5.0
# 5              NEGATIVOS              454612.0    1608.0         7.0
# 15             NEGATIVOS             1402382.0    1650.0         8.0
# 16                   NaN                   NaN       NaN         NaN
# 18             NEGATIVOS             1497679.0    1671.0         6.0
# 19                   NaN                   NaN       NaN         NaN
# 23                   NaN                   NaN       NaN         NaN
# 26             NEGATIVOS             2338381.0    1615.0         7.0
#
#    DS_UNIDADE  DT_ENTRADA HR_ENTRADA    DT_SAIDA  HR_SAIDA  \
# 2         UTI  07/12/2019   11:51:59  18/12/2019  13:48:48
# 3         UTI  10/01/2020   05:43:14  03/02/2020  14:04:26
# 4         UTI  17/04/2020   12:05:17  22/04/2020  11:39:07
# 5         UTI  23/04/2020   12:10:26  27/04/2020  12:27:38
# 15        UTI  27/03/2020   07:26:07  30/03/2020  13:23:12
# 16        NaN         NaN        NaN         NaN       NaN
# 18        UTI  31/03/2020   23:03:59  08/05/2020  21:50:13
# 19        NaN         NaN        NaN         NaN       NaN
# 23        NaN         NaN        NaN         NaN       NaN
# 26        UTI  29/03/2020   05:32:48  16/04/2020  18:50:00
#
#              DTHR_LEITO   DATA_HORA_ENTRADA  REENTRADA          DTHR_IN_UTI  \
# 2   26/11/2019 17:53:24 2019-12-07 11:51:59        1.0  07/12/2019 11:51:59
# 3   18/12/2019 13:48:48 2020-01-10 05:43:14        2.0  10/01/2020 05:43:14
# 4   03/02/2020 14:04:26 2020-04-17 12:05:17        3.0  17/04/2020 12:05:17
# 5   22/04/2020 11:39:07 2020-04-23 12:10:26        4.0  23/04/2020 12:10:26
# 15  11/03/2020 18:39:45 2020-03-27 07:26:07        1.0  27/03/2020 07:26:07
# 16                  NaN                 NaT        NaN                  NaN
# 18  09/03/2020 17:50:34 2020-03-31 23:03:59        1.0  31/03/2020 23:03:59
# 19                  NaN                 NaT        NaN                  NaN
# 23                  NaN                 NaT        NaN                  NaN
# 26  13/03/2020 10:34:49 2020-03-29 05:32:48        1.0  29/03/2020 05:32:48
#
#            DTHR_OUT_UTI  DIAS_PRE_UTI  DIAS_NA_UTI
# 2   18/12/2019 13:48:48     10.749016    11.081123
# 3   03/02/2020 14:04:26     22.662801    24.348056
# 4   22/04/2020 11:39:07     73.917257     4.981829
# 5   27/04/2020 12:27:38      1.021748     4.011944
# 15  30/03/2020 13:23:12     15.532199     3.247975
# 16                  NaN      0.076134     0.000000
# 18  08/05/2020 21:50:13     22.217650    37.948773
# 19                  NaN     20.785718     0.000000
# 23                  NaN      0.050139     0.000000
# 26  16/04/2020 18:50:00     15.790266    18.553611

# %%
#getDaysCountByRow(DF_REG_EST_UTI.values.tolist()[7], posREG=1, posALTA=27, posInUTI=119, posOutUTI=120)
# Out:
# (10.922141203703704, 0.0)

# %%
#print('REG', DF_REG_EST_UTI.values.tolist()[7][1])
# Out:
# REG 02/03/2021 15:11:00

# %%
DF_REG_EST_UTI
# Out:
#           ID        DTHR_REGISTRO PORTA_ENTRADA DATA_INICIO_SINTOMAS  \
# 0      26200  11/03/2021 16:00:00           NaN                  NaN
# 1      25919  06/03/2021 09:09:20           NaN                  NaN
# 2      25975  08/03/2021 08:11:00           NaN                  NaN
# 3      25922  06/03/2021 09:20:35           NaN                  NaN
# 4      26409  16/03/2021 12:06:39           NaN                  NaN
# ...      ...                  ...           ...                  ...
# 26541  26948  29/03/2021 17:55:00           NaN                  NaN
# 26542  25982  08/03/2021 10:02:01           NaN                  NaN
# 26543  25970  08/03/2021 03:40:00           NaN                  NaN
# 26544  26366  15/03/2021 14:38:15           NaN                  NaN
# 26545  26533  19/03/2021 10:54:01           NaN                  NaN
#
#       HISTORICO_VIAGEM PAIS_VISITADO CIDADES_VISITADAS DATA_RETORNO  \
# 0                  NaN           NaN               NaN          NaN
# 1                  NaN           NaN               NaN          NaN
# 2                  NaN           NaN               NaN          NaN
# 3                  NaN           NaN               NaN          NaN
# 4                  NaN           NaN               NaN          NaN
# ...                ...           ...               ...          ...
# 26541              NaN           NaN               NaN          NaN
# 26542              NaN           NaN               NaN          NaN
# 26543              NaN           NaN               NaN          NaN
# 26544              NaN           NaN               NaN          NaN
# 26545              NaN           NaN               NaN          NaN
#
#       COLETOU_AMOSTRA            LOCAL_COLETA          DATA_COLETA  \
# 0                 SIM        PRONTOPUC ADULTO  11/03/2021 16:28:16
# 1                 SIM     LABORATORIO CLINICO  06/03/2021 09:13:58
# 2                 SIM   PRONTOPUC ADULTO/INTE  08/03/2021 08:28:39
# 3                 SIM     LABORATORIO CLINICO  06/03/2021 09:21:54
# 4                 SIM     LABORATORIO CLINICO  16/03/2021 12:09:25
# ...               ...                     ...                  ...
# 26541             SIM  COVID SUS - INTERNACAO  29/03/2021 18:32:25
# 26542             SIM     LABORATORIO CLINICO  08/03/2021 10:09:48
# 26543             SIM        PRONTOPUC ADULTO  08/03/2021 04:11:21
# 26544             SIM     LABORATORIO CLINICO  15/03/2021 14:52:21
# 26545             SIM     LABORATORIO CLINICO  19/03/2021 11:00:07
#
#       PCR_INFLUENZA IFI_OUTRO_VIRUS PCR_COVID_19  \
# 0               NaN             NaN     NEGATIVO
# 1               NaN             NaN     NEGATIVO
# 2               NaN             NaN     NEGATIVO
# 3               NaN             NaN     POSITIVO
# 4               NaN             NaN     NEGATIVO
# ...             ...             ...          ...
# 26541           NaN             NaN     NEGATIVO
# 26542           NaN             NaN     POSITIVO
# 26543           NaN             NaN     NEGATIVO
# 26544           NaN             NaN     NEGATIVO
# 26545           NaN             NaN     NEGATIVO
#
#       STATUS_COVID_FROM_MRG_REG_EST  STATUS_COVID_ORDEM       DESFECHO  \
# 0                         NEGATIVOS                   3  NÃO INFORMADO
# 1                         NEGATIVOS                   3  NÃO INFORMADO
# 2                         NEGATIVOS                   3  NÃO INFORMADO
# 3                       CONFIRMADOS                   1  NÃO INFORMADO
# 4                         NEGATIVOS                   3  NÃO INFORMADO
# ...                             ...                 ...            ...
# 26541                     NEGATIVOS                   3  NÃO INFORMADO
# 26542                   CONFIRMADOS                   1  NÃO INFORMADO
# 26543                     NEGATIVOS                   3  NÃO INFORMADO
# 26544                     NEGATIVOS                   3  NÃO INFORMADO
# 26545                     NEGATIVOS                   3  NÃO INFORMADO
#
#        CD_ATENDIMENTO DS_TP_ATENDIMENTO  CD_PACIENTE     GENERO  \
# 0           1589566.0          URGENCIA    1824508.0  MASCULINO
# 1           1584147.0           EXTERNO    1825115.0   FEMININO
# 2           1584472.0         INTERNADO    1832839.0  MASCULINO
# 3           1584156.0           EXTERNO    1836699.0   FEMININO
# 4           1593409.0           EXTERNO    1836699.0   FEMININO
# ...               ...               ...          ...        ...
# 26541       1605174.0         INTERNADO    2323306.0   FEMININO
# 26542       1584995.0           EXTERNO    2323621.0  MASCULINO
# 26543       1584470.0          URGENCIA    2324835.0   FEMININO
# 26544       1592402.0           EXTERNO    2328466.0  MASCULINO
# 26545       1596851.0           EXTERNO    2334979.0   FEMININO
#
#                   IDADE SN_OBITO DIAGNOSTICO_SARS OBITO_SARS    TIPO_SAIDA  \
# 0      27,6929223744292        N              NÃO        NÃO  AMBULATORIAL
# 1      40,4545662100457        N              NÃO        NÃO  AMBULATORIAL
# 2      58,8792237442922        S              NÃO        NÃO         ÓBITO
# 3      53,7559360730594        N              NÃO        NÃO  AMBULATORIAL
# 4      53,7833333333333        N              NÃO        NÃO  AMBULATORIAL
# ...                 ...      ...              ...        ...           ...
# 26541   53,712100456621        N              NÃO        NÃO     INTERNADO
# 26542  35,9011415525114        N              NÃO        NÃO  AMBULATORIAL
# 26543  38,4408675799087        N              NÃO        NÃO  AMBULATORIAL
# 26544  30,6627853881279        N              NÃO        NÃO  AMBULATORIAL
# 26545  25,4929223744292        N              NÃO        NÃO  AMBULATORIAL
#
#       TIPO_OBITO            DTHR_ALTA CD_CID              DS_ESPECIALID_SAI  \
# 0            NaN  11/03/2021 19:21:00   R103                 CLINICA MEDICA
# 1            NaN                  NaN    NaN                     ACUPUNTURA
# 2            NaN  21/03/2021 18:59:44   A310                 CIRURGIA GERAL
# 3            NaN                  NaN    NaN                     NEUROLOGIA
# 4            NaN                  NaN    NaN                     NEUROLOGIA
# ...          ...                  ...    ...                            ...
# 26541        NaN                  NaN   C539              ONCOLOGIA CLINICA
# 26542        NaN                  NaN    NaN  MEDICINA FAMILIA E COMUNIDADE
# 26543        NaN  08/03/2021 08:19:00   R520                 CLINICA MEDICA
# 26544        NaN                  NaN    NaN                     NEUROLOGIA
# 26545        NaN                  NaN    NaN                     NEUROLOGIA
#
#       REINTER_30D CARATER_ATENDIMENTO  EMERG_SERVICO    EMERG_RISCO  \
# 0             NÃO            URGÊNCIA      PRONTOSUS        AMARELO
# 1             NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
# 2             NÃO            URGÊNCIA      PRONTOSUS        LARANJA
# 3             NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
# 4             NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
# ...           ...                 ...            ...            ...
# 26541         NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
# 26542         NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
# 26543         NÃO            URGÊNCIA      PRONTOPUC        LARANJA
# 26544         NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
# 26545         NÃO             ELETIVO  NÃO INFORMADO  NÃO INFORMADO
#
#       CID_DIAG_ATEND                                  CID_CAPITULO_DIAG  \
# 0               R103  Sintomas, sinais e achados anormais de exames ...
# 1               B349                         Infecciosas e parasitárias
# 2               A419                         Infecciosas e parasitárias
# 3               R520  Sintomas, sinais e achados anormais de exames ...
# 4               R520  Sintomas, sinais e achados anormais de exames ...
# ...              ...                                                ...
# 26541           C539                               Neoplasias (tumores)
# 26542           L910                        Pele e do tecido subcutâneo
# 26543           R520  Sintomas, sinais e achados anormais de exames ...
# 26544           Z010          Fatores que influenciam o estado de saúde
# 26545           B349                         Infecciosas e parasitárias
#
#       BLOCO_CENTRAL_ST HEMODINAMICA_ST EX_LAB_ST EX_IMG_ST EX_OUTROS_ST  \
# 0                  NÃO             NÃO       SIM       SIM          NÃO
# 1                  NÃO             NÃO       SIM       NÃO          NÃO
# 2                  SIM             NÃO       SIM       SIM          SIM
# 3                  NÃO             NÃO       SIM       NÃO          NÃO
# 4                  NÃO             NÃO       SIM       NÃO          NÃO
# ...                ...             ...       ...       ...          ...
# 26541              NÃO             NÃO       SIM       NÃO          NÃO
# 26542              NÃO             NÃO       SIM       NÃO          NÃO
# 26543              NÃO             NÃO       SIM       SIM          NÃO
# 26544              NÃO             NÃO       SIM       NÃO          NÃO
# 26545              NÃO             NÃO       SIM       NÃO          NÃO
#
#        CD_PACIENTE_FROM_ESTUDO COMPETENCIA PORTA_ENTRADA_FROM_ESTUDO  \
# 0                    1824508.0  11/03/2021                       NaN
# 1                    1825115.0  06/03/2021                       NaN
# 2                    1832839.0  08/03/2021                       NaN
# 3                    1836699.0  06/03/2021                       NaN
# 4                    1836699.0  06/03/2021                       NaN
# ...                        ...         ...                       ...
# 26541                2323306.0  29/03/2021                       NaN
# 26542                2323621.0  08/03/2021                       NaN
# 26543                2324835.0  08/03/2021                       NaN
# 26544                2328466.0  22/07/2020                       NaN
# 26545                2334979.0  12/05/2020                       NaN
#
#       DATA_INICIO_SINTOMAS_FROM_ESTUDO HISTORICO_VIAGEM_FROM_ESTUDO  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
# ...                                ...                          ...
# 26541                              NaN                          NaN
# 26542                              NaN                          NaN
# 26543                              NaN                          NaN
# 26544                              NaN                          NaN
# 26545                              NaN                          NaN
#
#       CIDADES_VISITADAS_FROM_ESTUDO LOCAL_COLETA_FROM_ESTUDO  \
# 0                               NaN         PRONTOPUC ADULTO
# 1                               NaN      LABORATORIO CLINICO
# 2                               NaN    PRONTOPUC ADULTO/INTE
# 3                               NaN      LABORATORIO CLINICO
# 4                               NaN      LABORATORIO CLINICO
# ...                             ...                      ...
# 26541                           NaN   COVID SUS - INTERNACAO
# 26542                           NaN      LABORATORIO CLINICO
# 26543                           NaN         PRONTOPUC ADULTO
# 26544                           NaN      LABORATORIO CLINICO
# 26545                           NaN      LABORATORIO CLINICO
#
#       DATA_COLETA_FROM_ESTUDO PCR_COVID_19_FROM_ESTUDO DESFECHO_FROM_ESTUDO  \
# 0         11/03/2021 16:28:16                 NEGATIVO                  NaN
# 1         06/03/2021 09:13:58                 NEGATIVO                  NaN
# 2         08/03/2021 08:28:39                 NEGATIVO           INTERNAÇÃO
# 3         06/03/2021 09:21:54                 NEGATIVO                  NaN
# 4         06/03/2021 09:21:54                 NEGATIVO                  NaN
# ...                       ...                      ...                  ...
# 26541     29/03/2021 18:32:25                 NEGATIVO           INTERNAÇÃO
# 26542     08/03/2021 10:09:48                 POSITIVO                  NaN
# 26543     08/03/2021 04:11:21                 NEGATIVO                  NaN
# 26544     22/07/2020 12:17:43                 NEGATIVO                  NaN
# 26545     12/05/2020 10:50:32                 NEGATIVO                  NaN
#
#       TIPO_REGISTRO SN_IFI_OV_SINCICIAL_RESP SN_IFI_OV_PARAINFLU3  \
# 0                 A                        N                    N
# 1                 A                        N                    N
# 2                 A                        N                    N
# 3                 A                        N                    N
# 4                 A                        N                    N
# ...             ...                      ...                  ...
# 26541             A                        N                    N
# 26542             A                        N                    N
# 26543             A                        N                    N
# 26544             A                        N                    N
# 26545             A                        N                    N
#
#       SN_IFI_OV_PARAINFLU2 SN_IFI_OV_PARAINFLU1 SN_IFI_OV_INFLUA  \
# 0                        N                    N                N
# 1                        N                    N                N
# 2                        N                    N                N
# 3                        N                    N                N
# 4                        N                    N                N
# ...                    ...                  ...              ...
# 26541                    N                    N                N
# 26542                    N                    N                N
# 26543                    N                    N                N
# 26544                    N                    N                N
# 26545                    N                    N                N
#
#       SN_IFI_OV_INFLUB SN_IFI_OV_ADENOVIRUS SN_CRIT_CONTATO_CASO_COVID  \
# 0                    N                    N                          N
# 1                    N                    N                          N
# 2                    N                    N                          N
# 3                    N                    N                          N
# 4                    N                    N                          N
# ...                ...                  ...                        ...
# 26541                N                    N                          N
# 26542                N                    N                          N
# 26543                N                    N                          N
# 26544                N                    N                          N
# 26545                N                    N                          N
#
#       SN_CRIT_CONTATO_CASO_SUSPEITO  SN_CRIT_PROF_SAUDE_HOSPITAL  \
# 0                                 N                          NaN
# 1                                 N                          NaN
# 2                                 N                          NaN
# 3                                 N                          NaN
# 4                                 N                          NaN
# ...                             ...                          ...
# 26541                             N                          NaN
# 26542                             N                          NaN
# 26543                             N                          NaN
# 26544                             N                          NaN
# 26545                             N                          NaN
#
#       SN_CRIT_PROF_SAUDE_OUT SN_CRIT_SRAG SN_CRIT_SINDROME_GRIPAL  \
# 0                          N            N                       N
# 1                          N            N                       N
# 2                          N            N                       N
# 3                          N            N                       N
# 4                          N            N                       N
# ...                      ...          ...                     ...
# 26541                      N            N                       N
# 26542                      N            N                       N
# 26543                      N            N                       N
# 26544                      N            N                       N
# 26545                      N            N                       N
#
#       SN_CRIT_IGNORADO SN_CRIT_OUTROS SN_CRIT_PROT_COVID19  \
# 0                    N              N                    N
# 1                    N              N                    N
# 2                    N              N                    N
# 3                    N              N                    N
# 4                    N              N                    N
# ...                ...            ...                  ...
# 26541                N              N                    N
# 26542                N              N                    N
# 26543                N              N                    N
# 26544                N              N                    N
# 26545                N              N                    N
#
#                ESTUDO_TP_EXPOSICAO ESTUDO_COMORB_PREV_HAS  \
# 0                              NaN                      N
# 1                              NaN                      N
# 2                              NaN                      N
# 3                              NaN                      N
# 4                              NaN                      N
# ...                            ...                    ...
# 26541                          NaN                      N
# 26542                          NaN                      N
# 26543                          NaN                      N
# 26544                          NaN                      N
# 26545  PROFISSIONAL DE SAUDE - HSL                      N
#
#       ESTUDO_COMORB_PREV_IAM ESTUDO_COMORB_PREV_IC ESTUDO_COMORB_PREV_DRC  \
# 0                          N                     N                      N
# 1                          N                     N                      N
# 2                          N                     N                      N
# 3                          N                     N                      N
# 4                          N                     N                      N
# ...                      ...                   ...                    ...
# 26541                      N                     N                      N
# 26542                      N                     N                      N
# 26543                      N                     N                      N
# 26544                      N                     N                      N
# 26545                      N                     N                      N
#
#       ESTUDO_COMORB_PREV_DMI ESTUDO_COMORB_PREV_DMII  \
# 0                          N                       N
# 1                          N                       N
# 2                          N                       N
# 3                          N                       N
# 4                          N                       N
# ...                      ...                     ...
# 26541                      N                       N
# 26542                      N                       N
# 26543                      N                       N
# 26544                      N                       N
# 26545                      N                       N
#
#       ESTUDO_COMORB_PREV_CARCINOMA ESTUDO_COMORB_PREV_ADENOMA  \
# 0                                N                          N
# 1                                N                          N
# 2                                N                          N
# 3                                N                          N
# 4                                N                          N
# ...                            ...                        ...
# 26541                            N                          N
# 26542                            N                          N
# 26543                            N                          N
# 26544                            N                          N
# 26545                            N                          N
#
#       ESTUDO_COMORB_PREV_LINFOMA ESTUDO_COMORB_PREV_AVC  \
# 0                              N                      N
# 1                              N                      N
# 2                              N                      N
# 3                              N                      N
# 4                              N                      N
# ...                          ...                    ...
# 26541                          N                      N
# 26542                          N                      N
# 26543                          N                      N
# 26544                          N                      N
# 26545                          N                      N
#
#       ESTUDO_COMORB_PREV_ASMA ESTUDO_COMORB_PREV_DPOC  \
# 0                           N                       N
# 1                           N                       N
# 2                           N                       N
# 3                           N                       N
# 4                           N                       N
# ...                       ...                     ...
# 26541                       N                       N
# 26542                       N                       N
# 26543                       N                       N
# 26544                       N                       N
# 26545                       N                       N
#
#       ESTUDO_COMORB_PREV_OBESIDADE ESTUDO_COMORB_PREV_EPILEPSIA  \
# 0                                N                            N
# 1                                N                            N
# 2                                N                            N
# 3                                N                            N
# 4                                N                            N
# ...                            ...                          ...
# 26541                            N                            N
# 26542                            N                            N
# 26543                            N                            N
# 26544                            N                            N
# 26545                            N                            N
#
#       ESTUDO_COMORB_PREV_HIGIDO ESTUDO_COMORB_PREV_OUTRAS  ESTUDO_CHARLSON  \
# 0                             N                       NaN              NaN
# 1                             N                       NaN              NaN
# 2                             N                       NaN              NaN
# 3                             N                       NaN              NaN
# 4                             N                       NaN              NaN
# ...                         ...                       ...              ...
# 26541                         N                       NaN              NaN
# 26542                         N                       NaN              NaN
# 26543                         N                       NaN              NaN
# 26544                         N                       NaN              NaN
# 26545                         N                       NaN              NaN
#
#       ESTUDO_FR_DIA_COLETA  ESTUDO_FC_DIA_COLETA ESTUDO_PA_DIA_COLETA  \
# 0                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 2                      NaN                   NaN                  NaN
# 3                      NaN                   NaN                  NaN
# 4                      NaN                   NaN                  NaN
# ...                    ...                   ...                  ...
# 26541                  NaN                   NaN                  NaN
# 26542                  NaN                   NaN                  NaN
# 26543                  NaN                   NaN                  NaN
# 26544                  NaN                   NaN                  NaN
# 26545                  NaN                   NaN                  NaN
#
#       ESTUDO_TEMPERATURA_DIA_COLETA ESTUDO_SATURACAO_DIA_COLETA  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ...                             ...                         ...
# 26541                           NaN                         NaN
# 26542                           NaN                         NaN
# 26543                           NaN                         NaN
# 26544                           NaN                         NaN
# 26545                           NaN                         NaN
#
#        ESTUDO_APACHE2  ESTUDO_RISCO ESTUDO_TRATAMENTO  \
# 0                 NaN           NaN               NaN
# 1                 NaN           NaN               NaN
# 2                 NaN           NaN               NaN
# 3                 NaN           NaN               NaN
# 4                 NaN           NaN               NaN
# ...               ...           ...               ...
# 26541             NaN           NaN               NaN
# 26542             NaN           NaN               NaN
# 26543             NaN           NaN               NaN
# 26544             NaN           NaN               NaN
# 26545             NaN           NaN               NaN
#
#       ESTUDO_COMORB_PREV_TX_ORG_SOL ESTUDO_CONDUTA ESTUDO_LOCAL_CONTAMINACAO  \
# 0                                 N              L                       NaN
# 1                                 N              L                       NaN
# 2                                 N              L                       NaN
# 3                                 N              L                       NaN
# 4                                 N              L                       NaN
# ...                             ...            ...                       ...
# 26541                             N              L                       NaN
# 26542                             N              L                       NaN
# 26543                             N              L                       NaN
# 26544                             N              L                       NaN
# 26545                             N              L                       NaN
#
#        ESTUDO_LOCAL_CONTAM_UI ESTUDO_DT_DESFECHO ESTUDO_COMORB_PREV_DESCON  \
# 0                         NaN                NaN                         N
# 1                         NaN                NaN                         N
# 2                         NaN                NaN                         N
# 3                         NaN                NaN                         N
# 4                         NaN                NaN                         N
# ...                       ...                ...                       ...
# 26541                     NaN                NaN                         N
# 26542                     NaN                NaN                         N
# 26543                     NaN                NaN                         N
# 26544                     NaN                NaN                         N
# 26545                     NaN                NaN                         N
#
#       ESTUDO_COMORB_PREV_DVP ESTUDO_COMORB_PREV_DEMENCIA  \
# 0                          N                           N
# 1                          N                           N
# 2                          N                           N
# 3                          N                           N
# 4                          N                           N
# ...                      ...                         ...
# 26541                      N                           N
# 26542                      N                           N
# 26543                      N                           N
# 26544                      N                           N
# 26545                      N                           N
#
#       ESTUDO_COMORB_PREV_DTC ESTUDO_COMORB_PREV_UP ESTUDO_COMORB_PREV_DFL  \
# 0                          N                     N                      N
# 1                          N                     N                      N
# 2                          N                     N                      N
# 3                          N                     N                      N
# 4                          N                     N                      N
# ...                      ...                   ...                    ...
# 26541                      N                     N                      N
# 26542                      N                     N                      N
# 26543                      N                     N                      N
# 26544                      N                     N                      N
# 26545                      N                     N                      N
#
#       ESTUDO_COMORB_PREV_DFM ESTUDO_COMORB_PREV_HEMIPLEGIA  \
# 0                          N                             N
# 1                          N                             N
# 2                          N                             N
# 3                          N                             N
# 4                          N                             N
# ...                      ...                           ...
# 26541                      N                             N
# 26542                      N                             N
# 26543                      N                             N
# 26544                      N                             N
# 26545                      N                             N
#
#       ESTUDO_COMORB_PREV_LEUCEMIA ESTUDO_COMORB_PREV_HIV  \
# 0                               N                      N
# 1                               N                      N
# 2                               N                      N
# 3                               N                      N
# 4                               N                      N
# ...                           ...                    ...
# 26541                           N                      N
# 26542                           N                      N
# 26543                           N                      N
# 26544                           N                      N
# 26545                           N                      N
#
#       ESTUDO_COMORB_PREV_TUL ESTUDO_COMORB_PREV_TUM STATUS_COVID_FROM_UTI  \
# 0                          N                      N                   NaN
# 1                          N                      N                   NaN
# 2                          N                      N             NEGATIVOS
# 3                          N                      N                   NaN
# 4                          N                      N                   NaN
# ...                      ...                    ...                   ...
# 26541                      N                      N                   NaN
# 26542                      N                      N                   NaN
# 26543                      N                      N                   NaN
# 26544                      N                      N                   NaN
# 26545                      N                      N                   NaN
#
#        CD_PACIENTE_FROM_UTI  CD_LEITO  CD_UNIDADE DS_UNIDADE  DT_ENTRADA  \
# 0                       NaN       NaN         NaN        NaN         NaN
# 1                       NaN       NaN         NaN        NaN         NaN
# 2                 1832839.0    1649.0         8.0        UTI  08/03/2021
# 3                       NaN       NaN         NaN        NaN         NaN
# 4                       NaN       NaN         NaN        NaN         NaN
# ...                     ...       ...         ...        ...         ...
# 26541                   NaN       NaN         NaN        NaN         NaN
# 26542                   NaN       NaN         NaN        NaN         NaN
# 26543                   NaN       NaN         NaN        NaN         NaN
# 26544                   NaN       NaN         NaN        NaN         NaN
# 26545                   NaN       NaN         NaN        NaN         NaN
#
#       HR_ENTRADA    DT_SAIDA  HR_SAIDA          DTHR_IN_UTI  \
# 0            NaN         NaN       NaN                  NaN
# 1            NaN         NaN       NaN                  NaN
# 2       13:31:53  18/03/2021  23:22:48  08/03/2021 13:31:53
# 3            NaN         NaN       NaN                  NaN
# 4            NaN         NaN       NaN                  NaN
# ...          ...         ...       ...                  ...
# 26541        NaN         NaN       NaN                  NaN
# 26542        NaN         NaN       NaN                  NaN
# 26543        NaN         NaN       NaN                  NaN
# 26544        NaN         NaN       NaN                  NaN
# 26545        NaN         NaN       NaN                  NaN
#
#               DTHR_OUT_UTI  DIAS_PRE_UTI  DIAS_NA_UTI
# 0                      NaN      0.139583     0.000000
# 1                      NaN           NaN          NaN
# 2      18/03/2021 23:22:48    112.633194  -112.410359
# 3                      NaN           NaN          NaN
# 4                      NaN           NaN          NaN
# ...                    ...           ...          ...
# 26541                  NaN           NaN          NaN
# 26542                  NaN           NaN          NaN
# 26543                  NaN      0.193750     0.000000
# 26544                  NaN           NaN          NaN
# 26545                  NaN           NaN          NaN
#
# [26546 rows x 124 columns]

# %%
#print('ALTA', DF_REG_EST_UTI.values.tolist()[7][27])
# Out:
# ALTA 13/03/2021 13:18:53

# %%
#print('InUTI', DF_REG_EST_UTI.values.tolist()[7][119])
# Out:
# InUTI nan

# %%
#print('OutUTI', DF_REG_EST_UTI.values.tolist()[7][120])
# Out:
# OutUTI nan

# %%
DF_REG_EST_UTI.loc[DF_REG_EST_UTI['CD_ATENDIMENTO']==1584472.0]
# Out:
#       ID        DTHR_REGISTRO PORTA_ENTRADA DATA_INICIO_SINTOMAS  \
# 2  25975  08/03/2021 08:11:00           NaN                  NaN
#
#   HISTORICO_VIAGEM PAIS_VISITADO CIDADES_VISITADAS DATA_RETORNO  \
# 2              NaN           NaN               NaN          NaN
#
#   COLETOU_AMOSTRA           LOCAL_COLETA          DATA_COLETA PCR_INFLUENZA  \
# 2             SIM  PRONTOPUC ADULTO/INTE  08/03/2021 08:28:39           NaN
#
#   IFI_OUTRO_VIRUS PCR_COVID_19 STATUS_COVID_FROM_MRG_REG_EST  \
# 2             NaN     NEGATIVO                     NEGATIVOS
#
#    STATUS_COVID_ORDEM       DESFECHO  CD_ATENDIMENTO DS_TP_ATENDIMENTO  \
# 2                   3  NÃO INFORMADO       1584472.0         INTERNADO
#
#    CD_PACIENTE     GENERO             IDADE SN_OBITO DIAGNOSTICO_SARS  \
# 2    1832839.0  MASCULINO  58,8792237442922        S              NÃO
#
#   OBITO_SARS TIPO_SAIDA TIPO_OBITO            DTHR_ALTA CD_CID  \
# 2        NÃO      ÓBITO        NaN  21/03/2021 18:59:44   A310
#
#   DS_ESPECIALID_SAI REINTER_30D CARATER_ATENDIMENTO EMERG_SERVICO EMERG_RISCO  \
# 2    CIRURGIA GERAL         NÃO            URGÊNCIA     PRONTOSUS     LARANJA
#
#   CID_DIAG_ATEND           CID_CAPITULO_DIAG BLOCO_CENTRAL_ST HEMODINAMICA_ST  \
# 2           A419  Infecciosas e parasitárias              SIM             NÃO
#
#   EX_LAB_ST EX_IMG_ST EX_OUTROS_ST  CD_PACIENTE_FROM_ESTUDO COMPETENCIA  \
# 2       SIM       SIM          SIM                1832839.0  08/03/2021
#
#   PORTA_ENTRADA_FROM_ESTUDO DATA_INICIO_SINTOMAS_FROM_ESTUDO  \
# 2                       NaN                              NaN
#
#   HISTORICO_VIAGEM_FROM_ESTUDO CIDADES_VISITADAS_FROM_ESTUDO  \
# 2                          NaN                           NaN
#
#   LOCAL_COLETA_FROM_ESTUDO DATA_COLETA_FROM_ESTUDO PCR_COVID_19_FROM_ESTUDO  \
# 2    PRONTOPUC ADULTO/INTE     08/03/2021 08:28:39                 NEGATIVO
#
#   DESFECHO_FROM_ESTUDO TIPO_REGISTRO SN_IFI_OV_SINCICIAL_RESP  \
# 2           INTERNAÇÃO             A                        N
#
#   SN_IFI_OV_PARAINFLU3 SN_IFI_OV_PARAINFLU2 SN_IFI_OV_PARAINFLU1  \
# 2                    N                    N                    N
#
#   SN_IFI_OV_INFLUA SN_IFI_OV_INFLUB SN_IFI_OV_ADENOVIRUS  \
# 2                N                N                    N
#
#   SN_CRIT_CONTATO_CASO_COVID SN_CRIT_CONTATO_CASO_SUSPEITO  \
# 2                          N                             N
#
#    SN_CRIT_PROF_SAUDE_HOSPITAL SN_CRIT_PROF_SAUDE_OUT SN_CRIT_SRAG  \
# 2                          NaN                      N            N
#
#   SN_CRIT_SINDROME_GRIPAL SN_CRIT_IGNORADO SN_CRIT_OUTROS  \
# 2                       N                N              N
#
#   SN_CRIT_PROT_COVID19 ESTUDO_TP_EXPOSICAO ESTUDO_COMORB_PREV_HAS  \
# 2                    N                 NaN                      N
#
#   ESTUDO_COMORB_PREV_IAM ESTUDO_COMORB_PREV_IC ESTUDO_COMORB_PREV_DRC  \
# 2                      N                     N                      N
#
#   ESTUDO_COMORB_PREV_DMI ESTUDO_COMORB_PREV_DMII ESTUDO_COMORB_PREV_CARCINOMA  \
# 2                      N                       N                            N
#
#   ESTUDO_COMORB_PREV_ADENOMA ESTUDO_COMORB_PREV_LINFOMA  \
# 2                          N                          N
#
#   ESTUDO_COMORB_PREV_AVC ESTUDO_COMORB_PREV_ASMA ESTUDO_COMORB_PREV_DPOC  \
# 2                      N                       N                       N
#
#   ESTUDO_COMORB_PREV_OBESIDADE ESTUDO_COMORB_PREV_EPILEPSIA  \
# 2                            N                            N
#
#   ESTUDO_COMORB_PREV_HIGIDO ESTUDO_COMORB_PREV_OUTRAS  ESTUDO_CHARLSON  \
# 2                         N                       NaN              NaN
#
#   ESTUDO_FR_DIA_COLETA  ESTUDO_FC_DIA_COLETA ESTUDO_PA_DIA_COLETA  \
# 2                  NaN                   NaN                  NaN
#
#   ESTUDO_TEMPERATURA_DIA_COLETA ESTUDO_SATURACAO_DIA_COLETA  ESTUDO_APACHE2  \
# 2                           NaN                         NaN             NaN
#
#    ESTUDO_RISCO ESTUDO_TRATAMENTO ESTUDO_COMORB_PREV_TX_ORG_SOL  \
# 2           NaN               NaN                             N
#
#   ESTUDO_CONDUTA ESTUDO_LOCAL_CONTAMINACAO  ESTUDO_LOCAL_CONTAM_UI  \
# 2              L                       NaN                     NaN
#
#   ESTUDO_DT_DESFECHO ESTUDO_COMORB_PREV_DESCON ESTUDO_COMORB_PREV_DVP  \
# 2                NaN                         N                      N
#
#   ESTUDO_COMORB_PREV_DEMENCIA ESTUDO_COMORB_PREV_DTC ESTUDO_COMORB_PREV_UP  \
# 2                           N                      N                     N
#
#   ESTUDO_COMORB_PREV_DFL ESTUDO_COMORB_PREV_DFM ESTUDO_COMORB_PREV_HEMIPLEGIA  \
# 2                      N                      N                             N
#
#   ESTUDO_COMORB_PREV_LEUCEMIA ESTUDO_COMORB_PREV_HIV ESTUDO_COMORB_PREV_TUL  \
# 2                           N                      N                      N
#
#   ESTUDO_COMORB_PREV_TUM STATUS_COVID_FROM_UTI  CD_PACIENTE_FROM_UTI  \
# 2                      N             NEGATIVOS             1832839.0
#
#    CD_LEITO  CD_UNIDADE DS_UNIDADE  DT_ENTRADA HR_ENTRADA    DT_SAIDA  \
# 2    1649.0         8.0        UTI  08/03/2021   13:31:53  18/03/2021
#
#    HR_SAIDA          DTHR_IN_UTI         DTHR_OUT_UTI  DIAS_PRE_UTI  \
# 2  23:22:48  08/03/2021 13:31:53  18/03/2021 23:22:48    112.633194
#
#    DIAS_NA_UTI
# 2  -112.410359

# %%
#getDaysCountByRow(DF_REG_EST_UTI.values.tolist()[2], posREG=1, posALTA=27, posInUTI=119, posOutUTI=120)
# Out:
# (112.63319444444444, -112.4103587962963)

# %%
#print('REG', DF_REG_EST_UTI.values.tolist()[2][1])
# Out:
# REG 08/03/2021 08:11:00

# %%
#print('ALTA', DF_REG_EST_UTI.values.tolist()[2][27])
# Out:
# ALTA 21/03/2021 18:59:44

# %%
#print('InUTI', DF_REG_EST_UTI.values.tolist()[2][119])
# Out:
# InUTI 23:22:48

# %%
#print('OutUTI', DF_REG_EST_UTI.values.tolist()[2][120])
# Out:
# OutUTI 08/03/2021 13:31:53
