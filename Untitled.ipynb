# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel(r'C:\Nucleo_IA\COVID\ML\dataset01.xlsx')

# %%
df.head(15)
# Out:
#     idade sexo  raca  tagabismo dm       has  ICC  oncologica  renal-hd  hiv  \
# 0      41    M     1          1  0   nenhuma  NaN         NaN       NaN  NaN
# 1      77    F     1          3  0         1  NaN         NaN       NaN  NaN
# 2      67    M     1          2  0         1  NaN         NaN       NaN  NaN
# 3      51    M     1          1  0         1  NaN         NaN       NaN  NaN
# 4      51    M     1          1  0         1  NaN         NaN       NaN  NaN
# 5      64    F     1          1  0         1  NaN         NaN       NaN  NaN
# 6      38    M     2          1  0  renal-hd  NaN         NaN       NaN  NaN
# 7      37    M     1          3  0       hiv  NaN         NaN       NaN  NaN
# 8      82    F     1          1  0         1  NaN         NaN       NaN  NaN
# 9      45    M     1          1  0   nenhuma  NaN         NaN       NaN  NaN
# 10     63    M     1          2  0         1  NaN         NaN       NaN  NaN
# ...

# %%
for data in df['has']:
    if data != 1:
        print('ok')
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ...
